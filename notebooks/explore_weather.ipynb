# %%
import requests
import pandas as pd

URL="https://api.open-meteo.com/v1/forecast"

params={
    "latitude": 40.71,
    "longitude":-74.01,
    "hourly": "temperature_2m,precipitation,wind_speed_10m"}

response=requests.get(URL, params=params)
data=response.json()

df_weather=pd.DataFrame(data["hourly"])

print(data.keys())
print(data.get("hourly", {}).keys())
print(df_weather.shape)
print(df_weather.head())
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units', 'hourly'])
# dict_keys(['time', 'temperature_2m', 'precipitation', 'wind_speed_10m'])
# (168, 4)
#                time  temperature_2m  precipitation  wind_speed_10m
# 0  2026-07-13T00:00            25.4            0.0            10.5
# 1  2026-07-13T01:00            22.9            0.0            12.2
# 2  2026-07-13T02:00            22.3            0.0             6.7
# 3  2026-07-13T03:00            22.3            0.0             6.2
# 4  2026-07-13T04:00            21.5            0.0             4.3
